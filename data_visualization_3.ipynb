# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("http://13.234.66.67/summer19/datasets/bank.csv")

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  ...  IsActiveMember EstimatedSalary Exited
# 0          1    15634602  Hargrave  ...               1       101348.88      1
# 1          2    15647311      Hill  ...               1       112542.58      0
# 2          3    15619304      Onio  ...               0       113931.57      1
# 3          4    15701354      Boni  ...               0        93826.63      0
# 4          5    15737888  Mitchell  ...               1        79084.10      0
#
# [5 rows x 14 columns]

# %%
df.shape
# Out:
# (10000, 14)

# %%
plt.bar(df["CreditScore"],df["Age"])
plt.xlabel("Creditscore")
plt.ylabel("Age")
# Out:
# Text(0, 0.5, 'Age')

# %%
plt.scatter(df["EstimatedSalary"],df["Age"])
plt.xlabel("EstimateSalary")
plt.ylabel("Age")
# Out:
# Text(0, 0.5, 'Age')

# %%
plt.bar(df["EstimatedSalary"],df["Balance"])
plt.ylabel("Balance")
plt.xlabel("EstimateSalary")
# Out:
# Text(0.5, 0, 'EstimateSalary')

# %%
plt.bar(df["Age"],df["Balance"])
plt.ylabel("Balance")
plt.xlabel("Age")
# Out:
# Text(0.5, 0, 'Age')

# %%
df.groupby(['Gender']).size().plot('pie',shadow=True, label='Gender' ,autopct='%1.1f%%')

# %%
df.groupby(['Geography']).size().plot('pie',shadow=True, label='Geography' ,autopct='%1.1f%%')

# %%
df[df['Gender']=='Female'].groupby('Geography').size().plot('pie',shadow=True, label='Geography' ,autopct='%1.1f%%')

# %%
df[df['Gender']=='Male'].groupby('Geography').size().plot('pie',shadow=True, label='Geography' ,autopct='%1.1f%%')

# %%
df[df['Geography']=='France'].groupby('Gender').size().plot('pie',shadow=True, label='France' ,autopct='%1.1f%%')

# %%
df[df['Geography']=='Spain'].groupby('Gender').size().plot('pie',shadow=True, label='Spain' ,autopct='%1.1f%%')

# %%
df[df['Geography']=='Germany'].groupby('Gender').size().plot('pie',shadow=True, label='Germany' ,autopct='%1.1f%%')
