# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
# reading image
img1 = cv2.imread("dog2.jpg")

# %%
# showing image 1
cv2_imshow(img1)       # use cv2.imshow() if not using google colab
# Out:
# <PIL.Image.Image image mode=RGB size=225x225 at 0x7F3DC41C1B70>

# %%
img1.shape
# Out:
# (225, 225, 3)

# %%
# loading second image
img2 = cv2.imread("dog3.jpg")

# %%
# showing img2
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=225x225 at 0x7F3DC40DA3C8>

# %%
img2.shape
# Out:
# (225, 225, 3)

# %%
img1.shape == img2.shape    # boyh pics are of same dimension
# Out:
# True

# %%
z = img2[20:100,70:150].copy()

# %%
z
# Out:
# array([[[131, 150, 135],
#         [125, 146, 131],
#         [110, 133, 119],
#         ...,
#         [ 44,  78, 114],
#         [ 44,  74, 109],
#         [ 38,  63,  95]],
#
#        [[124, 144, 132],
#         [119, 141, 129],
#         [111, 135, 125],
#         ...,
#         [ 68, 104, 140],
#         [ 39,  70, 103],
#         [  6,  30,  58]],
#
#        [[112, 135, 127],
#         [109, 133, 125],
#         [104, 130, 124],
#         ...,
#         [116, 155, 193],
#         [ 78, 109, 140],
#         [ 26,  51,  77]],
#
#        ...,
#
#        [[159, 207, 219],
#         [162, 210, 222],
#         [165, 213, 225],
#         ...,
#         [ 50,  68,  85],
#         [ 47,  68,  90],
#         [ 41,  66,  92]],
#
#        [[156, 204, 216],
#         [159, 207, 219],
#         [163, 211, 223],
#         ...,
#         [ 38,  58,  76],
#         [ 43,  66,  88],
#         [ 40,  65,  91]],
#
#        [[152, 200, 212],
#         [156, 204, 216],
#         [161, 209, 221],
# ...

# %%
cv2_imshow(z)
# Out:
# <PIL.Image.Image image mode=RGB size=80x80 at 0x7F3DC40DA278>

# %%
a = img1[20:100,70:150].copy()

# %%
cv2_imshow(a)
# Out:
# <PIL.Image.Image image mode=RGB size=80x80 at 0x7F3DC40DA160>

# %%
img1[20:100,70:150] = z

# %%
cv2_imshow(img1)
# Out:
# <PIL.Image.Image image mode=RGB size=225x225 at 0x7F3DC40DA6A0>

# %%
img2[20:100,70:150] = a

# %%
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=225x225 at 0x7F3DC40DA748>
